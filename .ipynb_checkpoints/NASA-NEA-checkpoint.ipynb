# %%
## DATA CLEANING ##

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import joypy
# %matplotlib inline
# %matplotlib notebook
import plotly.express as px

# %%
file = "/Users/mdcummings/Desktop/Data Analysis/My Projects/NASA - Nearest Earth Objects/NASA-NearEarthObjects/neo_v2.csv"

# %%
df = pd.read_csv(file)

# %%
df
# Out:
#              id                 name  est_diameter_min  est_diameter_max  \
# 0       2162635  162635 (2000 SS164)          1.198271          2.679415
# 1       2277475    277475 (2005 WK4)          0.265800          0.594347
# 2       2512244   512244 (2015 YE18)          0.722030          1.614507
# 3       3596030          (2012 BV13)          0.096506          0.215794
# 4       3667127          (2014 GE35)          0.255009          0.570217
# ...         ...                  ...               ...               ...
# 90831   3763337           (2016 VX1)          0.026580          0.059435
# 90832   3837603           (2019 AD3)          0.016771          0.037501
# 90833  54017201           (2020 JP3)          0.031956          0.071456
# 90834  54115824           (2021 CN5)          0.007321          0.016370
# 90835  54205447           (2021 TW7)          0.039862          0.089133
#
#        relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0           13569.249224   5.483974e+07         Earth          False
# 1           73588.726663   6.143813e+07         Earth          False
# 2          114258.692129   4.979872e+07         Earth          False
# 3           24764.303138   2.543497e+07         Earth          False
# 4           42737.733765   4.627557e+07         Earth          False
# ...                  ...            ...           ...            ...
# 90831       52078.886692   1.230039e+07         Earth          False
# 90832       46114.605073   5.432121e+07         Earth          False
# 90833        7566.807732   2.840077e+07         Earth          False
# 90834       69199.154484   6.869206e+07         Earth          False
# 90835       27024.455553   5.977213e+07         Earth          False
#
#        absolute_magnitude  hazardous
# 0                   16.73      False
# 1                   20.00       True
# 2                   17.83      False
# 3                   22.20      False
# 4                   20.09       True
# ...                   ...        ...
# 90831               25.00      False
# 90832               26.00      False
# 90833               24.60      False
# 90834               27.80      False
# 90835               24.12      False
#
# [90836 rows x 10 columns]

# %%
# Understand the data types in each column
df.dtypes
# Out:
# id                      int64
# name                   object
# est_diameter_min      float64
# est_diameter_max      float64
# relative_velocity     float64
# miss_distance         float64
# orbiting_body          object
# sentry_object            bool
# absolute_magnitude    float64
# hazardous                bool
# dtype: object

# %%
# Describe the data
df.describe()
# Out:
#                  id  est_diameter_min  est_diameter_max  relative_velocity  \
# count  9.083600e+04      90836.000000      90836.000000       90836.000000
# mean   1.438288e+07          0.127432          0.284947       48066.918918
# std    2.087202e+07          0.298511          0.667491       25293.296961
# min    2.000433e+06          0.000609          0.001362         203.346433
# 25%    3.448110e+06          0.019256          0.043057       28619.020645
# 50%    3.748362e+06          0.048368          0.108153       44190.117890
# 75%    3.884023e+06          0.143402          0.320656       62923.604633
# max    5.427591e+07         37.892650         84.730541      236990.128088
#
#        miss_distance  absolute_magnitude
# count   9.083600e+04        90836.000000
# mean    3.706655e+07           23.527103
# std     2.235204e+07            2.894086
# min     6.745533e+03            9.230000
# 25%     1.721082e+07           21.340000
# 50%     3.784658e+07           23.700000
# 75%     5.654900e+07           25.700000
# max     7.479865e+07           33.200000

# %%
# How many null values in each column?
df.isnull().sum()
# Out:
# id                    0
# name                  0
# est_diameter_min      0
# est_diameter_max      0
# relative_velocity     0
# miss_distance         0
# orbiting_body         0
# sentry_object         0
# absolute_magnitude    0
# hazardous             0
# dtype: int64

# %%
# Identifying the different sorts of null values
missing_value = ["N/a", "na", "n/a", "n/A", np.nan]
df = pd.read_csv(file, na_values = missing_value)

# %%
# How many of all variations of null are there per column
df.isnull().sum()
# Out:
# id                    0
# name                  0
# est_diameter_min      0
# est_diameter_max      0
# relative_velocity     0
# miss_distance         0
# orbiting_body         0
# sentry_object         0
# absolute_magnitude    0
# hazardous             0
# dtype: int64

# %%
# Plot a heat map showing the null values
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
# Remove null values
df = df.dropna()
df
# Out:
#              id                 name  est_diameter_min  est_diameter_max  \
# 0       2162635  162635 (2000 SS164)          1.198271          2.679415
# 1       2277475    277475 (2005 WK4)          0.265800          0.594347
# 2       2512244   512244 (2015 YE18)          0.722030          1.614507
# 3       3596030          (2012 BV13)          0.096506          0.215794
# 4       3667127          (2014 GE35)          0.255009          0.570217
# ...         ...                  ...               ...               ...
# 90831   3763337           (2016 VX1)          0.026580          0.059435
# 90832   3837603           (2019 AD3)          0.016771          0.037501
# 90833  54017201           (2020 JP3)          0.031956          0.071456
# 90834  54115824           (2021 CN5)          0.007321          0.016370
# 90835  54205447           (2021 TW7)          0.039862          0.089133
#
#        relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0           13569.249224   5.483974e+07         Earth          False
# 1           73588.726663   6.143813e+07         Earth          False
# 2          114258.692129   4.979872e+07         Earth          False
# 3           24764.303138   2.543497e+07         Earth          False
# 4           42737.733765   4.627557e+07         Earth          False
# ...                  ...            ...           ...            ...
# 90831       52078.886692   1.230039e+07         Earth          False
# 90832       46114.605073   5.432121e+07         Earth          False
# 90833        7566.807732   2.840077e+07         Earth          False
# 90834       69199.154484   6.869206e+07         Earth          False
# 90835       27024.455553   5.977213e+07         Earth          False
#
#        absolute_magnitude  hazardous
# 0                   16.73      False
# 1                   20.00       True
# 2                   17.83      False
# 3                   22.20      False
# 4                   20.09       True
# ...                   ...        ...
# 90831               25.00      False
# 90832               26.00      False
# 90833               24.60      False
# 90834               27.80      False
# 90835               24.12      False
#
# [90836 rows x 10 columns]

# %%
# Plot a heat map verifying the null values are removed
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
# Group the DataFrame by Last Name to see any duplicates
df_engine = df.groupby('id').count()
df_engine
# Out:
#           name  est_diameter_min  est_diameter_max  relative_velocity  \
# id
# 2000433      3                 3                 3                  3
# 2000719      1                 1                 1                  1
# 2001036      1                 1                 1                  1
# 2001566      5                 5                 5                  5
# 2001580      2                 2                 2                  2
# ...        ...               ...               ...                ...
# 54275849     1                 1                 1                  1
# 54275852     1                 1                 1                  1
# 54275853     1                 1                 1                  1
# 54275865     4                 4                 4                  4
# 54275914     1                 1                 1                  1
#
#           miss_distance  orbiting_body  sentry_object  absolute_magnitude  \
# id
# 2000433               3              3              3                   3
# 2000719               1              1              1                   1
# 2001036               1              1              1                   1
# 2001566               5              5              5                   5
# 2001580               2              2              2                   2
# ...                 ...            ...            ...                 ...
# 54275849              1              1              1                   1
# 54275852              1              1              1                   1
# 54275853              1              1              1                   1
# 54275865              4              4              4                   4
# 54275914              1              1              1                   1
#
#           hazardous
# id
# 2000433           3
# 2000719           1
# 2001036           1
# 2001566           5
# 2001580           2
# ...             ...
# 54275849          1
# 54275852          1
# 54275853          1
# 54275865          4
# 54275914          1
#
# [27423 rows x 9 columns]

# %%
# Get some statistics (can also include, 'min', 'max', 'mean')
df.groupby('id').miss_distance.agg(['mean'])
# Out:
#                   mean
# id
# 2000433   3.754117e+07
# 2000719   4.258288e+07
# 2001036   5.372124e+07
# 2001566   4.609560e+07
# 2001580   4.413007e+07
# ...                ...
# 54275849  2.211065e+07
# 54275852  1.781882e+07
# 54275853  9.777491e+06
# 54275865  1.313668e+07
# 54275914  2.458422e+07
#
# [27423 rows x 1 columns]

# %%
# Drop any unnecessary columns ('number')
df_ridge = df.drop(columns=['orbiting_body','sentry_object','hazardous', 'est_diameter_min','est_diameter_max'], axis=1)
df_ridge.head(50)

# df = df.drop('column_name', axis=1)
# where 1 is the axis number (0 for rows and 1 for columns.)

# Or, the drop() method accepts index/columns keywords as an alternative to specifying the axis. 
#So we can now just do:

# df = df.drop(columns=['column_nameA', 'column_nameB'])
# Out:
#           id                      name  relative_velocity  miss_distance  \
# 0    2162635       162635 (2000 SS164)       13569.249224   5.483974e+07
# 1    2277475         277475 (2005 WK4)       73588.726663   6.143813e+07
# 2    2512244        512244 (2015 YE18)      114258.692129   4.979872e+07
# 3    3596030               (2012 BV13)       24764.303138   2.543497e+07
# 4    3667127               (2014 GE35)       42737.733765   4.627557e+07
# 5   54138696               (2021 GY23)       34297.587778   4.058569e+07
# 6   54189957               (2021 PY40)       27529.472307   2.906912e+07
# 7   54230078                (2021 XD6)       57544.470083   5.511502e+07
# 8    2088213          88213 (2001 AF2)       56625.210122   6.903598e+07
# 9    3766065                 (2016 YM)       48425.840329   3.835526e+07
# 10  54049873                (2020 OT6)       58430.697200   3.833750e+07
# 11  54099949                (2020 XW4)       64393.928316   7.198311e+07
# 12  54104555                (2021 AW1)       38018.615291   5.209302e+07
# 13  54235433                 (2022 AM)       24323.046145   2.461759e+07
# 14   2198752        198752 (2005 EA60)       10402.002178   6.078930e+07
# 15   3069224              (2000 YT134)       74576.930760   5.988081e+07
# 16   3739154                (2016 AF2)       75486.090854   7.138706e+07
# 17   3795026                (2017 YU3)       70770.591144   2.771724e+07
# 18   3797456                (2018 AN2)       42111.044076   3.942128e+07
# 19   3825138                (2018 LC3)      104810.093720   1.883284e+07
# 20   3835974                (2018 VK1)       49452.240578   5.766709e+07
# 21   3842597                (2019 KN2)       27462.378012   3.891301e+07
# 22  54053939                (2020 RD4)       47644.448463   5.294885e+07
# 23   2506491        506491 (2003 UW29)      115899.180498   1.510102e+07
# 24   3329370                (2006 GB1)       33803.166561   7.039487e+07
# 25   3623582               (2013 AU27)       69871.977311   5.843872e+07
# 26   3768024                 (2017 CQ)       71487.940827   2.112332e+07
# 27   3781344                 (2017 RV)       48655.305132   3.279775e+07
# 28  54076362                (2020 UF5)       17906.491092   6.697931e+07
# 29  54105263                (2021 AZ4)      109370.376172   6.823170e+07
# 30  54232321                 (2022 AB)       67866.927071   6.797344e+07
# 31   2007480     7480 Norwan (1994 PC)       24889.185305   7.403522e+07
# 32   2020425         20425 (1998 VD35)       40625.288951   1.489180e+07
# 33   2337345        337345 (2001 KO20)       35852.709189   4.153028e+07
# 34   3608427                (2012 RO1)       50429.075188   6.849300e+07
# 35   3654336                (2013 XS3)       53877.169151   7.210312e+07
# 36  54016465                (2020 GF1)       18985.191913   4.632952e+07
# 37  54235525                (2022 AP1)       62986.288326   3.112155e+07
# 38   2002100  2100 Ra-Shalom (1978 RA)       52325.453650   6.817844e+07
# 39   2003362      3362 Khufu (1984 QA)       37279.210933   3.253063e+07
# 40   2004688            4688 (1980 WF)       25692.767376   2.544843e+07
# 41   2252558         252558 (2001 WT1)       39304.721509   7.076070e+07
# 42   2452334          452334 (2001 LB)       40893.824206   4.094082e+07
# 43   3067492              (2000 YS134)       17928.597659   9.980651e+06
# 44   3313974               (2006 BV39)       78622.563499   6.947473e+07
# 45   3379718                (2007 NL1)       58668.289891   4.297924e+07
# 46   3463175                (2009 LW2)       67427.241331   1.009472e+07
# 47   3572706                 (2011 OB)       93603.438892   7.148808e+07
# 48   3731680                 (2015 UK)       34034.944476   6.159111e+07
# 49   3740825                (2016 BN1)       45273.275408   6.441754e+07
#
#     absolute_magnitude
# 0                16.73
# 1                20.00
# 2                17.83
# 3                22.20
# 4                20.09
# 5                24.32
# 6                20.95
# 7                28.49
# 8                19.40
# 9                22.00
# 10               20.11
# 11               21.20
# 12               22.90
# 13               28.18
# 14               19.81
# 15               18.70
# 16               27.90
# 17               23.90
# 18               24.80
# 19               18.80
# 20               27.17
# 21               27.10
# 22               29.70
# 23               20.60
# 24               23.60
# 25               18.90
# 26               20.90
# 27               21.90
# 28               24.60
# 29               21.45
# 30               23.60
# 31               17.06
# 32               20.40
# 33               20.60
# 34               19.70
# 35               20.38
# 36               26.30
# 37               28.36
# 38               16.23
# 39               18.30
# 40               19.48
# 41               20.20
# 42               21.00
# 43               23.10
# 44               29.10
# 45               21.20
# 46               19.70
# 47               19.30
# 48               26.40
# 49               20.64

# %%
# Create bins for each category of magnitude
# Create the bins in which Data will be held
# Bins are 0, 10, 14, 17, 20, 23, 26, 29, 32.   
bins = [0, 9, 13, 16, 19, 22, 25, 28, 31, 34]

# Create the names for the five bins
group_names = ["Extremely Small", " Very Small", "Small", "Medium Small", "Medium", "Medium Large", "Large", "Very Large", "Extremely Large"]

# %%
# Use bins to create a new column for the magnitude
df_ridge["Size"] = pd.cut(df_ridge["absolute_magnitude"], bins, labels=group_names, include_lowest=True)
df_ridge
# Out:
#              id                 name  relative_velocity  miss_distance  \
# 0       2162635  162635 (2000 SS164)       13569.249224   5.483974e+07
# 1       2277475    277475 (2005 WK4)       73588.726663   6.143813e+07
# 2       2512244   512244 (2015 YE18)      114258.692129   4.979872e+07
# 3       3596030          (2012 BV13)       24764.303138   2.543497e+07
# 4       3667127          (2014 GE35)       42737.733765   4.627557e+07
# ...         ...                  ...                ...            ...
# 90831   3763337           (2016 VX1)       52078.886692   1.230039e+07
# 90832   3837603           (2019 AD3)       46114.605073   5.432121e+07
# 90833  54017201           (2020 JP3)        7566.807732   2.840077e+07
# 90834  54115824           (2021 CN5)       69199.154484   6.869206e+07
# 90835  54205447           (2021 TW7)       27024.455553   5.977213e+07
#
#        absolute_magnitude          Size
# 0                   16.73  Medium Small
# 1                   20.00        Medium
# 2                   17.83  Medium Small
# 3                   22.20  Medium Large
# 4                   20.09        Medium
# ...                   ...           ...
# 90831               25.00  Medium Large
# 90832               26.00         Large
# 90833               24.60  Medium Large
# 90834               27.80         Large
# 90835               24.12  Medium Large
#
# [90836 rows x 6 columns]

# %%
#Series
# we generate a pd.Series with the size for object's absolute magnitude 
# (used later for colors in the FacetGrid plot), and we create a new column in temp dataframe
size_mean_series = df_ridge.groupby('Size')['absolute_magnitude'].mean()
df_ridge['mean_magnitude'] = df_ridge['Size'].map(size_mean_series)
df_ridge
# Out:
#              id                 name  relative_velocity  miss_distance  \
# 0       2162635  162635 (2000 SS164)       13569.249224   5.483974e+07
# 1       2277475    277475 (2005 WK4)       73588.726663   6.143813e+07
# 2       2512244   512244 (2015 YE18)      114258.692129   4.979872e+07
# 3       3596030          (2012 BV13)       24764.303138   2.543497e+07
# 4       3667127          (2014 GE35)       42737.733765   4.627557e+07
# ...         ...                  ...                ...            ...
# 90831   3763337           (2016 VX1)       52078.886692   1.230039e+07
# 90832   3837603           (2019 AD3)       46114.605073   5.432121e+07
# 90833  54017201           (2020 JP3)        7566.807732   2.840077e+07
# 90834  54115824           (2021 CN5)       69199.154484   6.869206e+07
# 90835  54205447           (2021 TW7)       27024.455553   5.977213e+07
#
#        absolute_magnitude          Size  mean_magnitude
# 0                   16.73  Medium Small       18.066835
# 1                   20.00        Medium       20.698142
# 2                   17.83  Medium Small       18.066835
# 3                   22.20  Medium Large       23.609692
# 4                   20.09        Medium       20.698142
# ...                   ...           ...             ...
# 90831               25.00  Medium Large       23.609692
# 90832               26.00         Large       26.306475
# 90833               24.60  Medium Large       23.609692
# 90834               27.80         Large       26.306475
# 90835               24.12  Medium Large       23.609692
#
# [90836 rows x 7 columns]

# %%
# Create a ridge chart
# we generate a color palette with Seaborn.color_palette()
pal = sns.color_palette(palette='coolwarm', n_colors=8)

# in the sns.FacetGrid class, the 'hue' argument is the one that is the one that will be represented by colors with 'palette'
g = sns.FacetGrid(df_ridge, row='Size', hue='mean_magnitude', aspect=15, height=0.75, palette=pal)

# then we add the densities kdeplots for each size category
g.map(sns.kdeplot, 'absolute_magnitude',
      bw_adjust=1, clip_on=False,
      fill=True, alpha=1, linewidth=1.5)

# here we add a grey line that represents the contour of each kdeplot
g.map(sns.kdeplot, 'absolute_magnitude', 
      bw_adjust=1, clip_on=True, 
      color="grey", lw=1.5)

# here we add a horizontal line for each plot
g.map(plt.axhline, y=0,
      lw=1.5, clip_on=False)

# we loop over the FacetGrid figure axes (g.axes.flat) and add the category as text with the right color
# 
for i, ax in enumerate(g.axes.flat):
    ax.text(-1, 0.02, group_names[i-1],
            fontweight='regular', fontsize=12,
            color='b')
    
# we use matplotlib.Figure.subplots_adjust() function to get the subplots to overlap
g.fig.subplots_adjust(hspace=-0.3)

# eventually we remove axes titles, yticks and spines
g.set_titles("")
g.set(yticks=[])
# g.set_xticklabels(group_names)
# g.despine(bottom=True, left=True)

# plt.setp(ax.get_xticklabels(), fontsize=15, fontweight='bold')
plt.xlabel('Absolute Magnitude', fontweight='bold', fontsize=15)
g.fig.suptitle('Absolute Magnitude Distribution within NEA Size Categories',
               ha='right',
               fontsize=20,
               fontweight=20)

plt.show()

# %%
# Creating a scatter plot to see if there is any correlation between relative velocity and absolute magnitude
norm = plt.Normalize(1,4)
cmap = plt.cm.RdYlGn

fig,ax = plt.subplots()
sc = plt.scatter(df_ridge["relative_velocity"],df_ridge["absolute_magnitude"], s=df_ridge["absolute_magnitude"], cmap=cmap, norm=norm)

annot = ax.annotate("", xy=(0,0), xytext=(20,20),textcoords="offset points",
                    bbox=dict(boxstyle="round", fc="w"),
                    arrowprops=dict(arrowstyle="->"))
annot.set_visible(False)

def update_annot(ind):
    
    pos = sc.get_offsets()[ind["ind"][0]]
    annot.xy = pos
    text = "{}, {}".format(" ".join(list(map(str,ind["ind"]))), 
                           " ".join([names[n] for n in ind["ind"]]))
    annot.set_text(text)
    annot.get_bbox_patch().set_facecolor(cmap(norm(c[ind["ind"][0]])))
    annot.get_bbox_patch().set_alpha(0.4)
    

def hover(event):
    vis = annot.get_visible()
    if event.inaxes == ax:
        cont, ind = sc.contains(event)
        if cont:
            update_annot(ind)
            annot.set_visible(True)
            fig.canvas.draw_idle()
        else:
            if vis:
                annot.set_visible(False)
                fig.canvas.draw_idle()

fig.canvas.mpl_connect("motion_notify_event", hover)
plt.show(block=True)

# %%
# import plotly.express as px

fig = plt.scatter(df_ridge["relative_velocity"],df_ridge["absolute_magnitude"], s=df_ridge["absolute_magnitude"], cmap=cmap, norm=norm)
fig.update_traces(mode="markers+lines", hovertemplate=None)
fig.update_layout(hovermode="x")

fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/nr/jqfs4n8n3bvf1cmmq9_jmc5c0000gn/T/ipykernel_93979/1338592904.py in <module>
#       2
#       3 fig = plt.scatter(df_ridge["relative_velocity"],df_ridge["absolute_magnitude"], s=df_ridge["absolute_magnitude"], cmap=cmap, norm=norm)
# ----> 4 fig.update_traces(mode="markers+lines", hovertemplate=None)
#       5 fig.update_layout(hovermode="x")
#       6
#
# AttributeError: 'PathCollection' object has no attribute 'update_traces'
